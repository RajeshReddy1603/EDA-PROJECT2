# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.shape
# Out:
# (891, 12)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
a={
    "PassengerId":"passengerid",
     "Survived":"survived",
     "Pclass":"pclass",
     "Name":"name",
     "Sex":"sex",
     "Age":"age",
     "SibSp":"sibsp",
     "Parch":"parch",
     "Ticket":"ticket",
      "Fare":"fare",
      "Cabin":"cabin",
      "Embarked":"embarked"
}

# %%
df.rename(columns=a,inplace=True)

# %%
df
# Out:
#      passengerid  survived  pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   name     sex   age  sibsp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.columns
# Out:
# Index(['passengerid', 'survived', 'pclass', 'name', 'sex', 'age', 'sibsp',
#        'parch', 'ticket', 'fare', 'cabin', 'embarked'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# passengerid      0
# survived         0
# pclass           0
# name             0
# sex              0
# age            177
# sibsp            0
# parch            0
# ticket           0
# fare             0
# cabin          687
# embarked         2
# dtype: int64

# %%
df1=df.dropna()

# %%
df1.isna().sum()
# Out:
# passengerid    0
# survived       0
# pclass         0
# name           0
# sex            0
# age            0
# sibsp          0
# parch          0
# ticket         0
# fare           0
# cabin          0
# embarked       0
# dtype: int64

# %%
df.head(10)
# Out:
#    passengerid  survived  pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 name     sex   age  sibsp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df1.shape
# Out:
# (183, 12)

# %%
df.describe()
# Out:
#        passengerid    survived      pclass         age       sibsp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             parch        fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df1.head()
# Out:
#     passengerid  survived  pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
#
#                                                  name     sex   age  sibsp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     parch    ticket     fare cabin embarked
# 1       0  PC 17599  71.2833   C85        C
# 3       0    113803  53.1000  C123        S
# 6       0     17463  51.8625   E46        S
# 10      1   PP 9549  16.7000    G6        S
# 11      0    113783  26.5500  C103        S

# %%
new_columns=["passengerid","pclass","sex","age","name","ticket","cabin","parch","embarked","survived","sibsp","fare"]

# %%
df1=df1[new_columns]
df1
# Out:
#      passengerid  pclass     sex   age  \
# 1              2       1  female  38.0
# 3              4       1  female  35.0
# 6              7       1    male  54.0
# 10            11       3  female   4.0
# 11            12       1  female  58.0
# ..           ...     ...     ...   ...
# 871          872       1  female  47.0
# 872          873       1    male  33.0
# 879          880       1  female  56.0
# 887          888       1  female  19.0
# 889          890       1    male  26.0
#
#                                                   name    ticket        cabin  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  PC 17599          C85
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    113803         C123
# 6                              McCarthy, Mr. Timothy J     17463          E46
# 10                     Sandstrom, Miss. Marguerite Rut   PP 9549           G6
# 11                            Bonnell, Miss. Elizabeth    113783         C103
# ...

# %%
df.columns
# Out:
# Index(['passengerid', 'survived', 'pclass', 'name', 'sex', 'age', 'sibsp',
#        'parch', 'ticket', 'fare', 'cabin', 'embarked'],
#       dtype='object')

# %%
df2=df1.reset_index(drop=True)
df2
# Out:
#      passengerid  pclass     sex   age  \
# 0              2       1  female  38.0
# 1              4       1  female  35.0
# 2              7       1    male  54.0
# 3             11       3  female   4.0
# 4             12       1  female  58.0
# ..           ...     ...     ...   ...
# 178          872       1  female  47.0
# 179          873       1    male  33.0
# 180          880       1  female  56.0
# 181          888       1  female  19.0
# 182          890       1    male  26.0
#
#                                                   name    ticket        cabin  \
# 0    Cumings, Mrs. John Bradley (Florence Briggs Th...  PC 17599          C85
# 1         Futrelle, Mrs. Jacques Heath (Lily May Peel)    113803         C123
# 2                              McCarthy, Mr. Timothy J     17463          E46
# 3                      Sandstrom, Miss. Marguerite Rut   PP 9549           G6
# 4                             Bonnell, Miss. Elizabeth    113783         C103
# ...

# %%
df2.head()
# Out:
#    passengerid  pclass     sex   age  \
# 0            2       1  female  38.0
# 1            4       1  female  35.0
# 2            7       1    male  54.0
# 3           11       3  female   4.0
# 4           12       1  female  58.0
#
#                                                 name    ticket cabin  parch  \
# 0  Cumings, Mrs. John Bradley (Florence Briggs Th...  PC 17599   C85      0
# 1       Futrelle, Mrs. Jacques Heath (Lily May Peel)    113803  C123      0
# 2                            McCarthy, Mr. Timothy J     17463   E46      0
# 3                    Sandstrom, Miss. Marguerite Rut   PP 9549    G6      1
# 4                           Bonnell, Miss. Elizabeth    113783  C103      0
#
#   embarked  survived  sibsp     fare
# 0        C         1      1  71.2833
# 1        S         1      1  53.1000
# 2        S         0      0  51.8625
# 3        S         1      1  16.7000
# 4        S         1      0  26.5500

# %%
df2.shape
# Out:
# (183, 12)

# %%
df2.describe()
# Out:
#        passengerid      pclass         age       parch    survived  \
# count   183.000000  183.000000  183.000000  183.000000  183.000000
# mean    455.366120    1.191257   35.674426    0.475410    0.672131
# std     247.052476    0.515187   15.643866    0.754617    0.470725
# min       2.000000    1.000000    0.920000    0.000000    0.000000
# 25%     263.500000    1.000000   24.000000    0.000000    0.000000
# 50%     457.000000    1.000000   36.000000    0.000000    1.000000
# 75%     676.000000    1.000000   47.500000    1.000000    1.000000
# max     890.000000    3.000000   80.000000    4.000000    1.000000
#
#             sibsp        fare
# count  183.000000  183.000000
# mean     0.464481   78.682469
# std      0.644159   76.347843
# min      0.000000    0.000000
# 25%      0.000000   29.700000
# 50%      0.000000   57.000000
# 75%      1.000000   90.000000
# max      3.000000  512.329200

# %%
df2
# Out:
#      passengerid  pclass     sex   age  \
# 0              2       1  female  38.0
# 1              4       1  female  35.0
# 2              7       1    male  54.0
# 3             11       3  female   4.0
# 4             12       1  female  58.0
# ..           ...     ...     ...   ...
# 178          872       1  female  47.0
# 179          873       1    male  33.0
# 180          880       1  female  56.0
# 181          888       1  female  19.0
# 182          890       1    male  26.0
#
#                                                   name    ticket        cabin  \
# 0    Cumings, Mrs. John Bradley (Florence Briggs Th...  PC 17599          C85
# 1         Futrelle, Mrs. Jacques Heath (Lily May Peel)    113803         C123
# 2                              McCarthy, Mr. Timothy J     17463          E46
# 3                      Sandstrom, Miss. Marguerite Rut   PP 9549           G6
# 4                             Bonnell, Miss. Elizabeth    113783         C103
# ...

# %%
survived=df2.groupby(["sex","age"])["survived"].count().sort_values(ascending=False)

# %%
survived
# Out:
# sex     age
# female  24.0    7
# male    36.0    7
# female  36.0    4
#         39.0    4
#         35.0    4
#                ..
# male    60.0    1
#         64.0    1
#         70.0    1
#         71.0    1
#         80.0    1
# Name: survived, Length: 95, dtype: int64

# %%
survived=df2.groupby(["sex","age"])["survived"].count().sort_values(ascending=False)
plt.title("how many people survived")
plt.xlabel("sex")
plt.ylabel("age")
x=["pink","yellow"]
plt.bar(df2["sex"],df2["age"],color=x,edgecolor="blue")
# Out:
# <BarContainer object of 183 artists>

# %%
df2.head()
# Out:
#    passengerid  pclass     sex   age  \
# 0            2       1  female  38.0
# 1            4       1  female  35.0
# 2            7       1    male  54.0
# 3           11       3  female   4.0
# 4           12       1  female  58.0
#
#                                                 name    ticket cabin  parch  \
# 0  Cumings, Mrs. John Bradley (Florence Briggs Th...  PC 17599   C85      0
# 1       Futrelle, Mrs. Jacques Heath (Lily May Peel)    113803  C123      0
# 2                            McCarthy, Mr. Timothy J     17463   E46      0
# 3                    Sandstrom, Miss. Marguerite Rut   PP 9549    G6      1
# 4                           Bonnell, Miss. Elizabeth    113783  C103      0
#
#   embarked  survived  sibsp     fare
# 0        C         1      1  71.2833
# 1        S         1      1  53.1000
# 2        S         0      0  51.8625
# 3        S         1      1  16.7000
# 4        S         1      0  26.5500

# %%
number=df2.groupby(["pclass","sex"])["survived"].count()
number
# Out:
# pclass  sex
# 1       female    74
#         male      84
# 2       female     9
#         male       6
# 3       female     5
#         male       5
# Name: survived, dtype: int64

# %%
number=df2.groupby(["pclass","sex"])["survived"].count()
sns.barplot(x="pclass",hue="survived",y="sex",data=df2)
# Out:
# <Axes: xlabel='pclass', ylabel='sex'>

# %%
number=df2.groupby(["pclass","sex"])["survived"].count()
sns.barplot(x="pclass",y="survived",hue="sex",data=df2,palette={"female":"red","male":"yellow"})
# Out:
# <Axes: xlabel='pclass', ylabel='survived'>

# %%
df2.head()
# Out:
#    passengerid  pclass     sex   age  \
# 0            2       1  female  38.0
# 1            4       1  female  35.0
# 2            7       1    male  54.0
# 3           11       3  female   4.0
# 4           12       1  female  58.0
#
#                                                 name    ticket cabin  parch  \
# 0  Cumings, Mrs. John Bradley (Florence Briggs Th...  PC 17599   C85      0
# 1       Futrelle, Mrs. Jacques Heath (Lily May Peel)    113803  C123      0
# 2                            McCarthy, Mr. Timothy J     17463   E46      0
# 3                    Sandstrom, Miss. Marguerite Rut   PP 9549    G6      1
# 4                           Bonnell, Miss. Elizabeth    113783  C103      0
#
#   embarked  survived  sibsp     fare
# 0        C         1      1  71.2833
# 1        S         1      1  53.1000
# 2        S         0      0  51.8625
# 3        S         1      1  16.7000
# 4        S         1      0  26.5500

# %%
more_money=df2.groupby(["name","fare"])["fare"].count()
more_money
# Out:
# name                                             fare
# Allen, Miss. Elisabeth Walton                    211.3375    1
# Allison, Master. Hudson Trevor                   151.5500    1
# Allison, Miss. Helen Loraine                     151.5500    1
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  151.5500    1
# Anderson, Mr. Harry                              26.5500     1
#                                                             ..
# White, Mr. Percival Wayland                      77.2875     1
# White, Mr. Richard Frasar                        77.2875     1
# Wick, Miss. Mary Natalie                         164.8667    1
# Widener, Mr. Harry Elkins                        211.5000    1
# Young, Miss. Marie Grice                         135.6333    1
# Name: fare, Length: 183, dtype: int64

# %%
more_money=df2.groupby(["name","fare"])["fare"].count()
plt.plot("plot graph")
plt.xlabel("name")
plt.ylabel("fare")
plt.plot(df["name"],df["fare"],marker="*",color='yellow')

# %%
df2.head(10)
# Out:
#    passengerid  pclass     sex   age  \
# 0            2       1  female  38.0
# 1            4       1  female  35.0
# 2            7       1    male  54.0
# 3           11       3  female   4.0
# 4           12       1  female  58.0
# 5           22       2    male  34.0
# 6           24       1    male  28.0
# 7           28       1    male  19.0
# 8           53       1  female  49.0
# 9           55       1    male  65.0
#
#                                                 name    ticket        cabin  \
# 0  Cumings, Mrs. John Bradley (Florence Briggs Th...  PC 17599          C85
# 1       Futrelle, Mrs. Jacques Heath (Lily May Peel)    113803         C123
# 2                            McCarthy, Mr. Timothy J     17463          E46
# 3                    Sandstrom, Miss. Marguerite Rut   PP 9549           G6
# 4                           Bonnell, Miss. Elizabeth    113783         C103
# 5                              Beesley, Mr. Lawrence    248698          D56
# ...

# %%
df2["age"]=df2["age"].astype('int')

# %%
df2.head()
# Out:
#    passengerid  pclass     sex  age  \
# 0            2       1  female   38
# 1            4       1  female   35
# 2            7       1    male   54
# 3           11       3  female    4
# 4           12       1  female   58
#
#                                                 name    ticket cabin  parch  \
# 0  Cumings, Mrs. John Bradley (Florence Briggs Th...  PC 17599   C85      0
# 1       Futrelle, Mrs. Jacques Heath (Lily May Peel)    113803  C123      0
# 2                            McCarthy, Mr. Timothy J     17463   E46      0
# 3                    Sandstrom, Miss. Marguerite Rut   PP 9549    G6      1
# 4                           Bonnell, Miss. Elizabeth    113783  C103      0
#
#   embarked  survived  sibsp     fare
# 0        C         1      1  71.2833
# 1        S         1      1  53.1000
# 2        S         0      0  51.8625
# 3        S         1      1  16.7000
# 4        S         1      0  26.5500

# %%
df2["fare"]=df2["fare"].astype("int")

# %%
df2.head(10)
# Out:
#    passengerid  pclass     sex  age  \
# 0            2       1  female   38
# 1            4       1  female   35
# 2            7       1    male   54
# 3           11       3  female    4
# 4           12       1  female   58
# 5           22       2    male   34
# 6           24       1    male   28
# 7           28       1    male   19
# 8           53       1  female   49
# 9           55       1    male   65
#
#                                                 name    ticket        cabin  \
# 0  Cumings, Mrs. John Bradley (Florence Briggs Th...  PC 17599          C85
# 1       Futrelle, Mrs. Jacques Heath (Lily May Peel)    113803         C123
# 2                            McCarthy, Mr. Timothy J     17463          E46
# 3                    Sandstrom, Miss. Marguerite Rut   PP 9549           G6
# 4                           Bonnell, Miss. Elizabeth    113783         C103
# 5                              Beesley, Mr. Lawrence    248698          D56
# ...

# %%
cols=["sex","survived"]

# %%
survived=df2.groupby(cols)["survived"].value_counts()

# %%
survived
# Out:
# sex     survived
# female  0            6
#         1           82
# male    0           54
#         1           41
# Name: count, dtype: int64

# %%
survived=df2.groupby(cols)["survived"].value_counts()
x=["red","orange"]
plt.title("bar graph")
plt.xlabel("sex")
plt.ylabel("survived")
plt.bar(df2["sex"],df2["survived"],color=x)
# Out:
# <BarContainer object of 183 artists>

# %%
df2.head()
# Out:
#    passengerid  pclass     sex  age  \
# 0            2       1  female   38
# 1            4       1  female   35
# 2            7       1    male   54
# 3           11       3  female    4
# 4           12       1  female   58
#
#                                                 name    ticket cabin  parch  \
# 0  Cumings, Mrs. John Bradley (Florence Briggs Th...  PC 17599   C85      0
# 1       Futrelle, Mrs. Jacques Heath (Lily May Peel)    113803  C123      0
# 2                            McCarthy, Mr. Timothy J     17463   E46      0
# 3                    Sandstrom, Miss. Marguerite Rut   PP 9549    G6      1
# 4                           Bonnell, Miss. Elizabeth    113783  C103      0
#
#   embarked  survived  sibsp  fare
# 0        C         1      1    71
# 1        S         1      1    53
# 2        S         0      0    51
# 3        S         1      1    16
# 4        S         1      0    26

# %%
total=df2.groupby(["sex"])["fare"].sum()
total
# Out:
# sex
# female    7793
# male      6531
# Name: fare, dtype: int64

# %%
total=df2.groupby(["sex"])["fare"].sum()
result=df2.pivot_table(index="sex",values="fare")
result
# Out:
#              fare
# sex
# female  88.556818
# male    68.747368

# %%
import warnings
warnings.filterwarnings('ignore')
ages=pd.cut(df["age"],[0,25,80])
result=df2.pivot_table(index=["sex",ages],values="fare")
result
# Out:
#                       fare
# sex    age
# female (0, 25]   96.500000
#        (25, 80]  90.575000
# male   (0, 25]   65.894737
#        (25, 80]  68.138889
